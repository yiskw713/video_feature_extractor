# %%
import h5py
import io
from PIL import Image

# %%
input_frames=64
temp_downsamp_rate = 2

# %%
with h5py.File('./oJCxnjaCoyI_000385_000395.hdf5', 'r') as f:
    video = f['video']
    n_frames = len(video)
    print(n_frames)
    n_frames = 127
    start_frame = np.random.randint(
        0, n_frames - input_frames * temp_downsamp_rate)
    clip = []
    for i in range(start_frame, start_frame + input_frames * temp_downsamp_rate, temp_downsamp_rate):
        img = Image.open(io.BytesIO(video[i]))

        clip.append(img)
# Out:
# 300
# ----------------------------------------------------------
# ValueError               Traceback (most recent call last)
# <ipython-input-43-f943741939b0> in <module>
#       5     n_frames = 127
#       6     start_frame = np.random.randint(
# ----> 7         0, n_frames - input_frames * temp_downsamp_rate)
#       8     clip = []
#       9     for i in range(start_frame, start_frame + input_frames * temp_downsamp_rate, temp_downsamp_rate):
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: Range cannot be empty (low >= high) unless no samples are taken

# %%
for _ in range(10000000):
    start_frame = np.random.randint(
        0, n_frames - input_frames * temp_downsamp_rate)

# %%
n_frames - input_frames * temp_downsamp_rate <= 1
# Out:
# True

# %%
import pandas as pd

# %%
import argparse
import glob
import h5py
import numpy as np
import os
import pandas as pd
from utils.class_label_map import get_class_label_map


class a(object):
    def __init__(self):
        self.orig_train_csv = './dataset/original/kinetics_700_train.csv'
        self.th = 128
        self.n_classes = 700

        
args = a()

df_train = pd.read_csv('./dataset/kinetics_700_train.csv')

for df in [df_train]:
    # adding the number of frames to dataframe
    for i in range(len(df)):
        n_frames = np.random.randint(0, 300)
        df['n_frames'][i] = n_frames

        if i == 100:
            # remove videos which have fewer frames
            df_train = df[df['n_frames'] >= args.th]
            break
# Out:
# /home/cvrg/.pyenv/versions/torch/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_train
# Out:
#         label  class_id                                video  n_frames
# 0   abseiling         0  abseiling/oJCxnjaCoyI_000385_000395       294
# 2   abseiling         0  abseiling/XXulvmGzw60_000563_000573       262
# 3   abseiling         0  abseiling/-3B32lodo2M_000059_000069       179
# 6   abseiling         0  abseiling/-Cv3NwxG_8g_000087_000097       265
# 10  abseiling         0  abseiling/-JNfr9HZc5w_000113_000123       193
# 12  abseiling         0  abseiling/-Qhiiw9yJvc_000825_000835       178
# 13  abseiling         0  abseiling/-UAghPqLTBI_000130_000140       211
# 14  abseiling         0  abseiling/-utJO7UasYE_000122_000132       200
# 17  abseiling         0  abseiling/-Z1X9B-F04Q_000012_000022       132
# 19  abseiling         0  abseiling/0347ZoDXyP0_000095_000105       185
# 21  abseiling         0  abseiling/03NbvjuSoxk_000604_000614       224
# 25  abseiling         0  abseiling/0lPhr3f8_do_000011_000021       182
# 29  abseiling         0  abseiling/0S2Es_AMbGI_000015_000025       284
# 30  abseiling         0  abseiling/0s2mvbfzzyc_000014_000024       159
# 32  abseiling         0  abseiling/0UD6OoOFwqc_000078_000088       162
# 37  abseiling         0  abseiling/15z2zWbH65Y_000092_000102       254
# 38  abseiling         0  abseiling/1atkTs6LO6s_000037_000047       153
# 39  abseiling         0  abseiling/1g7n_PZzkmg_000000_000010       137
# 41  abseiling         0  abseiling/1igvMc3ze5M_000359_000369       153
# 42  abseiling         0  abseiling/1JT7K8Cpb_M_000005_000015       203
# 44  abseiling         0  abseiling/1nWkZlMdzos_000065_000075       183
# 45  abseiling         0  abseiling/1oG6YwxGfCc_000031_000041       294
# 47  abseiling         0  abseiling/1Qj6Mu_CpnM_000042_000052       290
# 49  abseiling         0  abseiling/20WaQ_z2oWM_000244_000254       222
# 50  abseiling         0  abseiling/27Ogzc9n4GQ_000116_000126       154
# 51  abseiling         0  abseiling/2bgFe5au7v4_000037_000047       210
# 53  abseiling         0  abseiling/2lujXIXQIg0_000052_000062       156
# 54  abseiling         0  abseiling/2pTztDoFiMc_000525_000535       169
# 55  abseiling         0  abseiling/2rX-H4RmyZA_000020_000030       160
# 56  abseiling         0  abseiling/2SRJgIEtZVs_000239_000249       130
# 57  abseiling         0  abseiling/2UXCC5iONM0_000067_000077       258
# 60  abseiling         0  abseiling/3BDlgjIAlaU_000061_000071       246
# 64  abseiling         0  abseiling/3EO1jQ_nayQ_000021_000031       236
# 65  abseiling         0  abseiling/3hAYiMA3B54_000117_000127       203
# 66  abseiling         0  abseiling/3J29xVFUn00_000040_000050       179
# 68  abseiling         0  abseiling/3L60SisVlbI_000033_000043       185
# 69  abseiling         0  abseiling/3NndJs2ASXk_000006_000016       297
# 71  abseiling         0  abseiling/3qafN6S_En4_000058_000068       282
# 73  abseiling         0  abseiling/3xZcUCuw1Bg_000332_000342       243
# 76  abseiling         0  abseiling/3YzplIZVXpM_000089_000099       238
# 77  abseiling         0  abseiling/40GRwg2Gsvk_000127_000137       247
# 81  abseiling         0  abseiling/4k7MUQJVevU_000241_000251       265
# 82  abseiling         0  abseiling/4KNvdZGNVRM_000765_000775       280
# 84  abseiling         0  abseiling/4lTtJeXACp4_000121_000131       242
# 87  abseiling         0  abseiling/4pmkLkrDTdA_000000_000010       168
# 88  abseiling         0  abseiling/4sCQ-EX6cIg_000021_000031       226
# 90  abseiling         0  abseiling/4UfTRS5bWPw_000000_000010       232
# 92  abseiling         0  abseiling/4VvQtg9lRK8_000186_000196       276
# 93  abseiling         0  abseiling/51GJ2uVXjvM_001007_001017       272
# 94  abseiling         0  abseiling/51taNPfG89o_000080_000090       137
# 96  abseiling         0  abseiling/5dmLwEjGgxs_000009_000019       254
# 99  abseiling         0  abseiling/5jB9jPrhIho_000159_000169       251
